# %% [markdown]
# <a href="https://colab.research.google.com/github/itseluriiiiii/bda_collab/blob/main/Program1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pyspark

# %%
from pyspark import SparkContext
sc=SparkContext()

# %%
rdd = sc.parallelize(["scala","java","hadoop","spark","akka","spark vs hadoop","pyspark","pyspark and spark"])

# %%
total_count = rdd.count()
print("number of words:",total_count)
# Out:
# number of words: 8

# %%
spark_words_rdd = rdd.filter(lambda X: "spark" in X)

# %%
spark_words=spark_words_rdd.collect()
print(spark_words)
# Out:
# ['spark', 'spark vs hadoop', 'pyspark', 'pyspark and spark']
